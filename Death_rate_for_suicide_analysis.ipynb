# %%
# importing necessary packages
import pandas as pd
import numpy as np

# %%
#importing the dataset
data = pd.read_csv('Death_rates_for_suicide_by_sex_race_Hispanic_origin_and_age_United.csv')
data
# Out:
#                     INDICATOR  \
# 0     Death rates for suicide
# 1     Death rates for suicide
# 2     Death rates for suicide
# 3     Death rates for suicide
# 4     Death rates for suicide
# ...                       ...
# 6385  Death rates for suicide
# 6386  Death rates for suicide
# 6387  Death rates for suicide
# 6388  Death rates for suicide
# 6389  Death rates for suicide
#
#                                                    UNIT  \
# 0     Deaths per 100,000 resident population, age-ad...
# 1     Deaths per 100,000 resident population, age-ad...
# 2     Deaths per 100,000 resident population, age-ad...
# 3     Deaths per 100,000 resident population, age-ad...
# 4     Deaths per 100,000 resident population, age-ad...
# ...                                                 ...
# 6385      Deaths per 100,000 resident population, crude
# 6386      Deaths per 100,000 resident population, crude
# 6387      Deaths per 100,000 resident population, crude
# ...

# %% [markdown]
# ## Task 1

# %%
# Exploratory Data Analysis(EDA)
data.head(10)
# Out:
#                  INDICATOR                                               UNIT  \
# 0  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 1  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 2  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 3  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 4  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 5  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 6  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 7  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 8  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
# 9  Death rates for suicide  Deaths per 100,000 resident population, age-ad...
#
#   STUB_NAME   STUB_LABEL  YEAR       AGE  ESTIMATE
# 0     Total  All persons  1950  All ages      13.2
# ...

# %%
data.tail(10)
# Out:
#                     INDICATOR                                           UNIT  \
# 6380  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6381  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6382  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6383  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6384  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6385  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6386  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6387  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6388  Death rates for suicide  Deaths per 100,000 resident population, crude
# 6389  Death rates for suicide  Deaths per 100,000 resident population, crude
#
#                                               STUB_NAME  \
# 6380  Sex, age and race and Hispanic origin (Single ...
# ...

# %%
data.describe(include='all')
# Out:
#                       INDICATOR  \
# count                      6390
# unique                        1
# top     Death rates for suicide
# freq                       6390
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN
#
#                                                  UNIT          STUB_NAME  \
# count                                            6390               6390
# unique                                              2                 12
# top     Deaths per 100,000 resident population, crude  Sex, age and race
# freq                                             5578               1596
# mean                                              NaN                NaN
# std                                               NaN                NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6390 entries, 0 to 6389
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   INDICATOR   6390 non-null   object
#  1   UNIT        6390 non-null   object
#  2   STUB_NAME   6390 non-null   object
#  3   STUB_LABEL  6390 non-null   object
#  4   YEAR        6390 non-null   int64
#  5   AGE         6390 non-null   object
#  6   ESTIMATE    5484 non-null   float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 349.6+ KB

# %%
#Checking for missing values
data.isnull().sum()
# Out:
# INDICATOR       0
# UNIT            0
# STUB_NAME       0
# STUB_LABEL      0
# YEAR            0
# AGE             0
# ESTIMATE      906
# dtype: int64

# %% [markdown]
# ## Task 2

# %%
# Calculating the mean of the Estimate Column
data['ESTIMATE'].mean()
# Out:
# 13.709810357403356

# %%
# Calculating the meadian of the Estimate Column
data['ESTIMATE'].median()
# Out:
# 10.5

# %%
# Calculating the mode of the Estimate Column
data['ESTIMATE'].mode()
# Out:
# 0    4.3
# Name: ESTIMATE, dtype: float64

# %%
# Calculating the standard deviation of the Estimate Column
data['ESTIMATE'].std()
# Out:
# 11.531805309076466

# %%
# Correlation 
data.corr(method='pearson')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Correlation
# ----> 2 data.corr(method='pearson')
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %% [markdown]
# ### My Dataset has only one numeric feature, so data.corr() will not work on the dataset.
